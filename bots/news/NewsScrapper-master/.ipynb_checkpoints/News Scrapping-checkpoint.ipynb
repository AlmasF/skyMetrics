# %%
from lxml import html
import requests
import pandas as pd
from bs4 import BeautifulSoup
from lxml.html import fromstring
import re
import lxml.html as lh
from datetime import datetime
import numpy as np
from openpyxl import load_workbook

# %%
print('4/ scraping Parlam-senate https://www.parlam.kz/ru/mazhilis/sent-to-the-senate')
page = requests.get('https://www.parlam.kz/ru/mazhilis/sent-to-the-senate')
soup = BeautifulSoup(page.text, 'html.parser')


table = soup.find('table', {"class": "table col-sm-12 table-bordered table-striped table-condensed cf"})


def pre_process_table(table):

    rows = [x for x in table.find_all('tr')]

    num_rows = len(rows)

    num_cols = max([len(x.find_all(['th','td'])) for x in rows])

    header_rows_set = [x.find_all(['th', 'td']) for x in rows if len(x.find_all(['th', 'td']))>num_cols/2]

    num_cols_set = []

    for header_rows in header_rows_set:
        num_cols = 0
        for cell in header_rows:
            row_span, col_span = get_spans(cell)
            num_cols+=len([cell.getText()]*col_span)

        num_cols_set.append(num_cols)

    num_cols = max(num_cols_set)

    return (rows, num_rows, num_cols)


def get_spans(cell):
        if cell.has_attr('rowspan'):
            rep_row = int(cell.attrs['rowspan'])
        else: 
            rep_row = 1
        if cell.has_attr('colspan'):
            rep_col = int(cell.attrs['colspan'])
        else: 
            rep_col = 1 

        return (rep_row, rep_col)

def process_rows(rows, num_rows, num_cols):
    data = pd.DataFrame(np.ones((num_rows, num_cols))*np.nan)
                
    for i, row in enumerate(rows):
        try:
            col_stat = data.iloc[i,:][data.iloc[i,:].isnull()].index[0]
        except IndexError:
            print(i, row)

        for j, cell in enumerate(row.find_all(['td', 'th'])):
            
            rep_row, rep_col = get_spans(cell)

            while any(data.iloc[i,col_stat:col_stat+rep_col].notnull()):
                col_stat+=1

            data.iloc[i:i+rep_row,col_stat:col_stat+rep_col] = cell.getText()
            if col_stat<data.shape[1]-1:
                col_stat+=rep_col

    return data

def main(table):
    rows, num_rows, num_cols = pre_process_table(table)
    df = process_rows(rows, num_rows, num_cols)
    return(df)


  
        
rows, num_rows, num_cols = pre_process_table(table)
df = process_rows(rows, num_rows, num_cols)



df.drop(df.index[0], inplace = True)
df.rename(columns=df.iloc[0], inplace = True)
df.drop(df.index[0], inplace = True)
df = df.replace('\n','', regex=True)
#
df.replace(re.compile('none'), 'Нету законопроекта', inplace=True)
df.replace(re.compile('.*docx*'), 'Чтобы посмотреть законодательство нажмите на ссылку https://www.parlam.kz/mazhilis/', inplace=True)
df
# Out:
# 4/ scraping Parlam-senate https://www.parlam.kz/ru/mazhilis/sent-to-the-senate
#           Дата                                       Наименование  \
# 2   02.02.2022  О ратификации Соглашения о трансграничном пере...
# 3   26.01.2022  О ратификации Протокола о внесении изменений в...
# 4   19.01.2022  О ратификации Протокола о внесении изменений в...
# 5   19.01.2022  О внесении изменения в Закон Республики Казахс...
# 6   19.01.2022  О внесении изменений и дополнений в Конституци...
# 7   12.01.2022  О ратификации Соглашения между Правительством ...
# 8   10.01.2022  О внесении изменений и дополнений в Закон Респ...
# 9   06.01.2022  О внесении изменений и дополнений в некоторые ...
# 10  22.12.2021  О ратификации Договора между Республикой Казах...
# 28  Чтобы посмотреть законодательство нажмите на с...
# 29  Чтобы посмотреть законодательство нажмите на с...
# 30  Чтобы посмотреть законодательство нажмите на с...
# 31  Чтобы посмотреть законодательство нажмите на с...
# 32  Чтобы посмотреть законодательство нажмите на с...
# 33  Чтобы посмотреть законодательство нажмите на с...
# 34  Чтобы посмотреть законодательство нажмите на с...
# 35  Чтобы посмотреть законодательство нажмите на с...
# 36  Чтобы посмотреть законодательство нажмите на с...
# 37  Чтобы посмотреть законодательство нажмите на с...
# 38  Чтобы посмотреть законодательство нажмите на с...
# 39  Чтобы посмотреть законодательство нажмите на с...
# 40  Чтобы посмотреть законодательство нажмите на с...
# 41  Чтобы посмотреть законодательство нажмите на с...
# 42  Чтобы посмотреть законодательство нажмите на с...
# 43  Чтобы посмотреть законодательство нажмите на с...
# 44  Чтобы посмотреть законодательство нажмите на с...
# 45  Чтобы посмотреть законодательство нажмите на с...
# 46  Чтобы посмотреть законодательство нажмите на с...

# %%
print('1/ scraping AKORDA/Legal_acts https://www.akorda.kz/ru/legal_acts')
page = requests.get('https://www.akorda.kz/ru/legal_acts')
soup = BeautifulSoup(page.text, 'html.parser')

news_name=[]

news_name_list = soup.find_all('h3')
for news in news_name_list:
      if news.find('a'):
        news_name.append(news.find('a')['href'])
        news_name.append(news.find('a').text)
        
links, names = news_name[::2], news_name[1::2]

for i in range(len(links)):
    links[i] = "https://www.akorda.kz"+links[i]
        
date=[]

for date_time in soup.find_all('h5'):
    date.append(date_time.text)
    
source = list(range(len(names)))
for i in range(len(names)):
    source[i] = "Акорда (события)"
    
df1 = pd.DataFrame(columns = ['Сайт', 'Новость', 'Дата', 'Ссылка'])

df1['Сайт'] = source
df1['Новость'] = names
df1['Дата'] = date
df1['Ссылка'] = links

df1
# Out:
# 1/ scraping AKORDA/Legal_acts https://www.akorda.kz/ru/legal_acts
#                Сайт                                            Новость  \
# 0  Акорда (события)                      О назначении Оспанбекова А.К.
# 1  Акорда (события)  Распоряжением Главы государства Алишев Руслан ...
# 2  Акорда (события)  Распоряжением Главы государства Бабакумаров Ер...
# 3  Акорда (события)  Главой государства подписан Закон Республики К...
# 4  Акорда (события)  Главой государства подписан Конституционный за...
# 5  Акорда (события)  Распоряжением Главы государства Жолманов Азама...
# 6  Акорда (события)  Распоряжением Главы государства Жоламанов Аска...
# 7  Акорда (события)  Распоряжением Главы государства Журабаев Болат...
# 8  Акорда (события)                        О назначении Пирматова Г.О.
#
#                    Дата                                             Ссылка
# 0  12 февраля 2022 года  https://www.akorda.kz/ru/o-naznachenii-ospanbe...
# 1   9 февраля 2022 года  https://www.akorda.kz/ru/rasporyazheniem-glavy...
# 2   9 февраля 2022 года  https://www.akorda.kz/ru/rasporyazheniem-glavy...
# 3   7 февраля 2022 года  https://www.akorda.kz/ru/glavoy-gosudarstva-po...
# 4   7 февраля 2022 года  https://www.akorda.kz/ru/glavoy-gosudarstva-po...
# 5   7 февраля 2022 года  https://www.akorda.kz/ru/rasporyazheniem-glavy...
# 6   3 февраля 2022 года  https://www.akorda.kz/ru/rasporyazheniem-glavy...
# 7   3 февраля 2022 года  https://www.akorda.kz/ru/rasporyazheniem-glavy...
# 8   3 февраля 2022 года  https://www.akorda.kz/ru/o-naznachenii-pirmato...

# %%
print('2/ scraping SENATE https://senate.parlam.kz/ru-RU/lawProjects/index?p=2')
page = requests.get('https://senate.parlam.kz/ru-RU/lawProjects/index?p=2')
soup = BeautifulSoup(page.text, 'html.parser')

news_table = []
news_table_info = []

news_table_list = soup.find_all('td')

for title in news_table_list:
    if title.find('a'):
        news_table.append(title.find('a')['href'])
        news_table.append(title.text.strip())
    else: 
        news_table_info.append(title.text.strip())

links, names = news_table[::2], news_table[1::2]

for i in range(len(links)):
    links[i] = "https://senate.parlam.kz"+links[i]

source = list(range(len(names)))
for i in range(len(names)):
    source[i] = "Сенат (новости)"

id_number, register_date, register_number, decision_date = news_table_info[::4], news_table_info[1::4], news_table_info[2::4], news_table_info[3::4]


df2 = pd.DataFrame(columns = ['Сайт', 'Новость', 'Дата Регистраций', 'Номер Регистраций','Дата принятия решения', 'Ссылка'])

df2['Сайт'] = source
df2['Новость'] = names
df2['Дата Регистраций'] = register_date
df2['Номер Регистраций'] = register_number
df2['Дата принятия решения'] = decision_date
df2['Ссылка'] = links

df2
# Out:
# 2/ scraping SENATE https://senate.parlam.kz/ru-RU/lawProjects/index?p=2
#                Сайт                                            Новость  \
# 0   Сенат (новости)  О внесении изменений в некоторые законодательн...
# 1   Сенат (новости)  О внесении изменений и дополнений в некоторые ...
# 2   Сенат (новости)  О  ратификации Соглашения о сотрудничестве по ...
# 3   Сенат (новости)  О ратификации  Соглашения  между Правительство...
# 4   Сенат (новости)  О  ратификации  Соглашения   между  Правительс...
# 5   Сенат (новости)  О внесении изменений и дополнений в некоторые ...
# 6   Сенат (новости)  О внесении изменений и дополнений в некоторые ...
# 7   Сенат (новости)  О внесении изменений и дополнений в некоторые ...
# 8   Сенат (новости)  О   внесении   изменений  и  дополнений  в  не...
# 9   Сенат (новости)  О внесении изменений и дополнений в Кодекс Рес...
# 10  Сенат (новости)  О внесении изменений и дополнений в некоторые ...
# 11  Сенат (новости)             Об ответственном обращении с животными
# 12  Сенат (новости)  О внесении изменений и дополнения в некоторые ...
# 13  Сенат (новости)  О внесении дополнения в Кодекс Республики Каза...
# 14  Сенат (новости)  О внесении изменений и дополнений в Кодекс Рес...
#
#    Дата Регистраций Номер Регистраций Дата принятия решения  \
# 0        20.01.2022             № 163            27.01.2022
# 1        20.01.2022             № 162            02.02.2022
# 2        24.11.2021            № 4307            20.01.2022
# 3        18.11.2021            № 4189            30.12.2021
# 4        18.11.2021            № 4188            13.01.2022
# 5        10.12.2021            № 4526            29.12.2021
# 6        02.12.2021            № 4397            29.12.2021
# 7        11.12.2021            № 4533            23.12.2021
# 8        03.12.2021            № 4404            23.12.2021
# 9        23.11.2021            № 4255            23.12.2021
# 10       23.11.2021            № 4254            23.12.2021
# 11       23.11.2021            № 4253            23.12.2021
# 12       10.12.2021            № 4530            23.12.2021
# 13       16.11.2021            № 4139            20.12.2021
# 14       16.11.2021            № 4138            20.12.2021
#
#                                                Ссылка
# 0   https://senate.parlam.kz/ru-RU/lawProjects/det...
# 1   https://senate.parlam.kz/ru-RU/lawProjects/det...
# 2   https://senate.parlam.kz/ru-RU/lawProjects/det...
# 3   https://senate.parlam.kz/ru-RU/lawProjects/det...
# 4   https://senate.parlam.kz/ru-RU/lawProjects/det...
# 5   https://senate.parlam.kz/ru-RU/lawProjects/det...
# 6   https://senate.parlam.kz/ru-RU/lawProjects/det...
# 7   https://senate.parlam.kz/ru-RU/lawProjects/det...
# 8   https://senate.parlam.kz/ru-RU/lawProjects/det...
# 9   https://senate.parlam.kz/ru-RU/lawProjects/det...
# 10  https://senate.parlam.kz/ru-RU/lawProjects/det...
# 11  https://senate.parlam.kz/ru-RU/lawProjects/det...
# 12  https://senate.parlam.kz/ru-RU/lawProjects/det...
# 13  https://senate.parlam.kz/ru-RU/lawProjects/det...
# 14  https://senate.parlam.kz/ru-RU/lawProjects/det...

# %%
print('3/ scraping Parlam https://www.parlam.kz/ru/mazhilis/news')
page = requests.get('https://www.parlam.kz/ru/mazhilis/news')
soup = BeautifulSoup(page.text, 'html.parser')

text = []
links = []

news_link = soup.find_all('div' , {"class": "list"})

for link in news_link:
    if link.find('a'):
        links.append(link.find('a')['href'])
    if link.find('div', {"class": "col-md-10"}):
        text.append(link.text.strip().splitlines())
        
date = [i[0] for i in text]
title = [i[1] for i in text]

source = list(range(len(title)))
for i in range(len(title)):
    source[i] = "Мажилис (законопроекты)"
    
for i in range(len(links)):
    links[i] = "https://www.parlam.kz"+links[i]

df3 = pd.DataFrame(columns = ['Сайт', 'Новость', 'Дата', 'Ссылка'])

df3['Сайт'] = source
df3['Новость'] = title
df3['Дата'] = date
df3['Ссылка'] = links

df3
# Out:
# 3/ scraping Parlam https://www.parlam.kz/ru/mazhilis/news
#                        Сайт  \
# 0   Мажилис (законопроекты)
# 1   Мажилис (законопроекты)
# 2   Мажилис (законопроекты)
# 3   Мажилис (законопроекты)
# 4   Мажилис (законопроекты)
# 5   Мажилис (законопроекты)
# 6   Мажилис (законопроекты)
# 7   Мажилис (законопроекты)
# 8   Мажилис (законопроекты)
# 9   Мажилис (законопроекты)
# 10  Мажилис (законопроекты)
# 11  Мажилис (законопроекты)
#
#                                               Новость        Дата  \
# 0   Бюро Мажилиса зарегистрировало депутатскую гру...  11.02.2022
# 1   В Мажилисе презентованы поправки по вопросам у...  10.02.2022
# 2   В Мажилисе обсуждены вопросы соблюдения прав ч...  10.02.2022
# 3   Мажилис одобрил в первом чтении законопроект п...  09.02.2022
# 4   Мажилис одобрил в первом чтении законодательны...  09.02.2022
# 5   Спикеры палат парламентов Казахстана и Узбекис...  09.02.2022
# 6   В Мажилисе презентован законопроект «О личном ...  07.02.2022
# 7   Е.Кошанов: встречи депутатов Мажилиса в регион...  04.02.2022
# 8   Мажилис одобрил в первом чтении законодательны...  02.02.2022
# 9   Мажилис одобрил законодательные поправки по во...  02.02.2022
# 10        Ерлан Кошанов избран Председателем Мажилиса  01.02.2022
# 11  Н.Нигматулин: работа в Мажилисе – это был важн...  01.02.2022
#
#                                                Ссылка
# 0   https://www.parlam.kz/ru/mazhilis/news-details...
# 1   https://www.parlam.kz/ru/mazhilis/news-details...
# 2   https://www.parlam.kz/ru/mazhilis/news-details...
# 3   https://www.parlam.kz/ru/mazhilis/news-details...
# 4   https://www.parlam.kz/ru/mazhilis/news-details...
# 5   https://www.parlam.kz/ru/mazhilis/news-details...
# 6   https://www.parlam.kz/ru/mazhilis/news-details...
# 7   https://www.parlam.kz/ru/mazhilis/news-details...
# 8   https://www.parlam.kz/ru/mazhilis/news-details...
# 9   https://www.parlam.kz/ru/mazhilis/news-details...
# 10  https://www.parlam.kz/ru/mazhilis/news-details...
# 11  https://www.parlam.kz/ru/mazhilis/news-details...

# %%
print('5/ scraping Prime-minister https://primeminister.kz/ru/news')
page = requests.get('https://primeminister.kz/ru/news')
soup = BeautifulSoup(page.text, 'html.parser')


links = [item['href'] for item in soup.select('a.article')]

text=[]
date = []

news_name_list = soup.find_all('h3')

for title in news_name_list:
    text.append(title.text.replace("\n", '').split('\r'))

for item in soup.find_all(class_="article__date"):
    date.append(item.text)

date = [x.replace("\r\n","") for x in date]

source = list(range(len(text)))
for i in range(len(text)):
    source[i] = "Премьер-Министра Республики Казахстан"
    

for i in range(len(links)):
    links[i] = "https://primeminister.kz/ru/news"+links[i]

df5 = pd.DataFrame(columns = ['Сайт', 'Новость', 'Дата', 'Ссылка'])

df5['Сайт'] = source
df5['Новость'] = text
df5['Дата'] = date
df5['Ссылка'] = links

df5
# Out:
# 5/ scraping Prime-minister https://primeminister.kz/ru/news
#                                     Сайт  \
# 0  Премьер-Министра Республики Казахстан
# 1  Премьер-Министра Республики Казахстан
# 2  Премьер-Министра Республики Казахстан
# 3  Премьер-Министра Республики Казахстан
# 4  Премьер-Министра Республики Казахстан
# 5  Премьер-Министра Республики Казахстан
# 6  Премьер-Министра Республики Казахстан
# 7  Премьер-Министра Республики Казахстан
#
#                                              Новость  \
# 0  [Р. Скляр встретился с Президентом Туркмениста...
# 1  [А. Смаилов провел переговоры с Президентом Уз...
# 2  [Казахстанские предприниматели получат возможн...
# 3  [Правительством РК рассмотрен ряд конкретных м...
# 4  [При поддержке Правительства РК в Азербайджан ...
# 5  [В Мангистауской области сформирован запас по ...
# 6  [В нынешнем году в Алматы будет создано не мен...
# 7  [В Алматинской области начата работа по возмещ...
#
#                                                 Дата  \
# 0                  12                Фев 2022    ...
# 1                  11                Фев 2022    ...
# 2                  10                Фев 2022    ...
# 3                  10                Фев 2022    ...
# 4                  09                Фев 2022    ...
# 5                  08                Фев 2022    ...
# 6                  08                Фев 2022    ...
# 7                  08                Фев 2022    ...
#
#                                               Ссылка
# 0  https://primeminister.kz/ru/news/ru/news/r-skl...
# 1  https://primeminister.kz/ru/news/ru/news/a-sma...
# 2  https://primeminister.kz/ru/news/ru/news/kazah...
# 3  https://primeminister.kz/ru/news/ru/news/pravi...
# 4  https://primeminister.kz/ru/news/ru/news/pri-p...
# 5  https://primeminister.kz/ru/news/ru/news/v-man...
# 6  https://primeminister.kz/ru/news/ru/news/v-nyn...
# 7  https://primeminister.kz/ru/news/ru/news/v-alm...

# %%
print('/ scraping KGD.GOV http://kgd.gov.kz/ru/news/archive ...')
page = requests.get('http://kgd.gov.kz/ru/news/archive')
tree = html.fromstring(page.content)

titles = tree.xpath('//div[@class="col-md-7 col-xs-12"]/a/text()')

dates = tree.xpath('//div[@class="date"]/strong/a/text()')
     
links = tree.xpath('//div[@class="col-md-7 col-xs-12"]/a/@href')
for i in range(len(links)):
    links[i] = "http://kgd.gov.kz"+links[i]
    
source = list(range(len(titles)))
for i in range(len(titles)):
    source[i] = "КГД.ГОВ (новости)"

df6 = pd.DataFrame(columns = ['Сайт', 'Новость', 'Дата', 'Ссылка'])

df6['Сайт'] = source
df6['Новость'] = titles
df6['Дата'] = dates
df6['Ссылка'] = links

df6
# Out:
# / scraping KGD.GOV http://kgd.gov.kz/ru/news/archive ...
#                 Сайт                                            Новость  \
# 0  КГД.ГОВ (новости)  Учебный курс на тему: «Обучение работе со скан...
# 1  КГД.ГОВ (новости)  Информация по количеству автотранспорта, ожида...
# 2  КГД.ГОВ (новости)  1 086 618 долларов США наличными пытались выве...
# 3  КГД.ГОВ (новости)                                    Хоргос и кинжал
# 4  КГД.ГОВ (новости)           Конкурс «100 Лучших Специалистов РК2022»
# 5  КГД.ГОВ (новости)  Информация по количеству автотранспорта, ожида...
# 6  КГД.ГОВ (новости)  Технические неполадки в работе Web-приложения ...
# 7  КГД.ГОВ (новости)  В аэропорту столицы за 2021 год выявлено cвыше...
# 8  КГД.ГОВ (новости)  Информация по количеству автотранспорта, ожида...
# 9  КГД.ГОВ (новости)  Проект приказа Министра финансов "О внесении и...
#
#          Дата                                             Ссылка
# 0  17.02.2022  http://kgd.gov.kz/ru/news/uchebnyy-kurs-na-tem...
# 1  17.02.2022  http://kgd.gov.kz/ru/news/informaciya-po-kolic...
# 2  16.02.2022  http://kgd.gov.kz/ru/news/1-086-618-dollarov-s...
# 3  16.02.2022  http://kgd.gov.kz/ru/news/horgos-i-kinzhal-1-1...
# 4  16.02.2022  http://kgd.gov.kz/ru/news/konkurs-100-luchshih...
# 5  16.02.2022  http://kgd.gov.kz/ru/news/informaciya-po-kolic...
# 6  15.02.2022  http://kgd.gov.kz/ru/news/tehnicheskie-nepolad...
# 7  15.02.2022  http://kgd.gov.kz/ru/news/v-aeroportu-stolicy-...
# 8  15.02.2022  http://kgd.gov.kz/ru/news/informaciya-po-kolic...
# 9  14.02.2022  http://kgd.gov.kz/ru/news/proekt-prikaza-minis...

# %%
ex = pd.concat([df1, df3, df5, df6], ignore_index=True)
ex.to_excel('./output.xlsx')
print("Saved to ./output.xlsx\nOpen FINAL.xlsm and press update button")
# Out:
# Saved to ./output.xlsx
# Open FINAL.xlsm and press update button

# %%
path = r"./output.xlsx"

book = load_workbook(path)
writer = pd.ExcelWriter(path, engine = 'openpyxl')
writer.book = book
df.to_excel(writer, sheet_name = 'x3')
df2.to_excel(writer, sheet_name = 'x4')
writer.save()
writer.close()
